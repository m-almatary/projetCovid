# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.integrate import odeint
from scipy import optimize, integrate
import random

from sir import SIRModel

# %% [markdown]
# # Data 1

# %%
data1 = pd.read_csv("data_1.csv",sep=',')
data1.head()

t = list(data1.t)
I = list(data1.I)
a = SIRModel()
a.fit(t,I,55000000)
print("beta", a.beta, "gamma", a.gamma_)
S,I,R=a.predict(t,55000000, I[0])
plt.plot(t,data1.I, "o")
plt.plot(t,I)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/scipy/integrate/odepack.py:247: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# /home_local/isduser/UE20/projetCovid/data/FR/sir.py:30: RuntimeWarning: overflow encountered in double_scalars
#   sus = -betas * y[0] * y[1] / newN
# beta 1.0001369194765957 gamma 0.09999554141737468

# %% [markdown]
# # Data 2

# %%
data2 = pd.read_csv("data_2.csv",sep=',')
data2.head()

t = list(data2.t)
I = list(data2.I)
a = SIRModel()
a.fit(t,I,67000)
print("beta", a.beta, "gamma", a.gamma_)
S,I,R=a.predict(t,67000, I[0])
plt.plot(t,data2.I, "o")
plt.plot(t,I)
# Out:
# beta 0.009961475900428148 gamma 0.004965696782790491

# %% [markdown]
# # Data 3

# %%
data3 = pd.read_csv("data_3.csv",sep=',')
data3.head()

t = list(data3.t)
I = list(data3.I)
a = SIRModel()
a.fit(t,I,7700000000)
print("beta", a.beta, "gamma", a.gamma_)
S,I,R=a.predict(t,7700000000, I[0])
plt.plot(t,data3.I, "o")
plt.plot(t,I)
# Out:
# /home_local/isduser/UE20/projetCovid/data/FR/sir.py:31: RuntimeWarning: overflow encountered in double_scalars
#   rec = gammas * y[1]
# beta 0.49916020885616635 gamma 0.1991959768031217
